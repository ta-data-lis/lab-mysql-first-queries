# %%
import pandas as pd

# %%
applestore = pd.read_csv("C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\lab-mysql-first-queries\\AppleStore.csv")
applestore.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
#import library
import mysql.connector
from sqlalchemy import create_engine

# %%
host = 'localhost'
port = 3306
dbname = 'lab_mysql_first_queries'
user = 'root'
password = password

# %%
# insert parameters 
cnx = create_engine(f"mysql+mysqlconnector://{user}:{password}@{host}/{dbname}").connect()

# %%
#send the tables to MySQL
applestore.to_sql('applestore', con = cnx, if_exists = "replace")
