# %%
import pymysql
import sqlalchemy
import pandas as pd
import getpass

# %%
import mysql.connector

# %%
pip install SQLAlchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#connection to sql from python

# %%
pwd = getpass.getpass()
cnx = mysql.connector.connect(user = 'root',
                             password = pwd,
                             host = 'localhost',
                             database = 'sakila')
# Out:
# ········

# %%
#check if the connection was successful

# %%
cnx.is_connected()
# Out:
# True

# %%
#we need to define the object we will use to interact with database
cursor = cnx.cursor()

# %%
cursor

# %%
#we want to creat aquerry
#we will write code in sql syntax

query = ("select * from sakila.actor;")

# %%
cursor.execute(query)

# %%
results = cursor.fetchall()

# %%
results
# Out:
# [(1, 'PENELOPE', 'GUINESS', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (2, 'NICK', 'WAHLBERG', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (3, 'ED', 'CHASE', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (4, 'JENNIFER', 'DAVIS', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (5, 'JOHNNY', 'LOLLOBRIGIDA', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (6, 'BETTE', 'NICHOLSON', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (7, 'GRACE', 'MOSTEL', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (8, 'MATTHEW', 'JOHANSSON', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (9, 'JOE', 'SWANK', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (10, 'CHRISTIAN', 'GABLE', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (11, 'ZERO', 'CAGE', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (12, 'KARL', 'BERRY', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (13, 'UMA', 'WOOD', datetime.datetime(2006, 2, 15, 4, 34, 33)),
#  (14, 'VIVIEN', 'BERGEN', datetime.datetime(2006, 2, 15, 4, 34, 33)),
# ...

# %%
for item in results:
    print("ful name: ", item[1] +" "+ item[2])
# Out:
# ful name:  PENELOPE GUINESS
# ful name:  NICK WAHLBERG
# ful name:  ED CHASE
# ful name:  JENNIFER DAVIS
# ful name:  JOHNNY LOLLOBRIGIDA
# ful name:  BETTE NICHOLSON
# ful name:  GRACE MOSTEL
# ful name:  MATTHEW JOHANSSON
# ful name:  JOE SWANK
# ful name:  CHRISTIAN GABLE
# ful name:  ZERO CAGE
# ful name:  KARL BERRY
# ful name:  UMA WOOD
# ful name:  VIVIEN BERGEN
# ful name:  CUBA OLIVIER
# ful name:  FRED COSTNER
# ful name:  HELEN VOIGHT
# ful name:  DAN TORN
# ful name:  BOB FAWCETT
# ful name:  LUCILLE TRACY
# ful name:  KIRSTEN PALTROW
# ful name:  ELVIS MARX
# ful name:  SANDRA KILMER
# ful name:  CAMERON STREEP
# ful name:  KEVIN BLOOM
# ful name:  RIP CRAWFORD
# ful name:  JULIA MCQUEEN
# ful name:  WOODY HOFFMAN
# ful name:  ALEC WAYNE
# ful name:  SANDRA PECK
# ful name:  SISSY SOBIESKI
# ful name:  TIM HACKMAN
# ful name:  MILLA PECK
# ful name:  AUDREY OLIVIER
# ful name:  JUDY DEAN
# ful name:  BURT DUKAKIS
# ful name:  VAL BOLGER
# ful name:  TOM MCKELLEN
# ...

# %%
actors = pd.DataFrame(results)
actors
# Out:
#        0         1             2                   3
# 0      1  PENELOPE       GUINESS 2006-02-15 04:34:33
# 1      2      NICK      WAHLBERG 2006-02-15 04:34:33
# 2      3        ED         CHASE 2006-02-15 04:34:33
# 3      4  JENNIFER         DAVIS 2006-02-15 04:34:33
# 4      5    JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33
# ..   ...       ...           ...                 ...
# 195  196      BELA        WALKEN 2006-02-15 04:34:33
# 196  197     REESE          WEST 2006-02-15 04:34:33
# 197  198      MARY        KEITEL 2006-02-15 04:34:33
# 198  199     JULIA       FAWCETT 2006-02-15 04:34:33
# 199  200     THORA        TEMPLE 2006-02-15 04:34:33
#
# [200 rows x 4 columns]

# %%
cursor.description
# Out:
# [('actor_id', 2, None, None, None, None, 0, 49699, 63),
#  ('first_name', 253, None, None, None, None, 0, 4097, 255),
#  ('last_name', 253, None, None, None, None, 0, 20489, 255),
#  ('last_update', 7, None, None, None, None, 0, 9345, 63)]
